# %% [markdown]
# <a href="https://colab.research.google.com/github/jiban-khatri/Pandas/blob/main/pandas_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series form LIST

# %%
# series from lists

country = ["Nepal", "India", "Bhutan", "USA", "Australia"]
pd.Series(country)
# Out:
# 0        Nepal
# 1        India
# 2       Bhutan
# 3          USA
# 4    Australia
# dtype: object

# %%
# integers

runs = [10,32,10,101,65]
pd.Series(runs)
# Out:
# 0     10
# 1     32
# 2     10
# 3    101
# 4     65
# dtype: int64

# %%
# custom index

marks = [66, 70,64,68,72]
subs = ["nepali", "social", "english", "account", "maths"]

pd.Series(marks, index=subs)
# Out:
# nepali     66
# social     70
# english    64
# account    68
# maths      72
# dtype: int64

# %%
#  setting a name

marks = [66, 70,64,68,72]
subs = ["nepali", "social", "english", "account", "maths"]

my_marks = pd.Series(marks, index=subs, name = "jiban mark's")
my_marks
# Out:
# nepali     66
# social     70
# english    64
# account    68
# maths      72
# Name: jiban mark's, dtype: int64

# %% [markdown]
# # Series from Dictionary

# %%
marks = {
    "english" : 64,
    "nepali" : 66,
    "social" : 70,
    "maths" : 72,
    "computer" : 47,
    "account" : 70
}

marks_series = pd.Series(marks, name = "Jiban Marks")
print(marks_series)
# Out:
# english     64
# nepali      66
# social      70
# maths       72
# computer    47
# account     70
# Name: Jiban Marks, dtype: int64

# %% [markdown]
# # Series Attributes

# %%
#  size

marks_series.size
# Out:
# 6

# %%
# dtype

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Jiban Marks'

# %%
# is_unique
marks_series.is_unique
# Out:
# False

# %%
# index

marks_series.index
# Out:
# Index(['english', 'nepali', 'social', 'maths', 'computer', 'account'], dtype='object')

# %%
# values

marks_series.values
# Out:
# array([64, 66, 70, 72, 47, 70])

# %% [markdown]
# # Series using read_csv

# %%
# with one col (col -> column)

subs_ser = pd.read_csv('/content/subs.csv').squeeze()
print(subs_ser)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#  with 2 col(column)

virat_ser = pd.read_csv("/content/kohli_ipl.csv", index_col='match_no').squeeze()

print(virat_ser)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv("/content/bollywood.csv", index_col = "movie").squeeze()


print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series Methods

# %%
# head and tail
# ---> head for first 5 default
virat_ser.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
#  tail for last 5 default
virat_ser.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample ---> randomly one set default but can add also how many you want

virat_ser.sample()
# Out:
# match_no
# 129    54
# Name: runs, dtype: int64

# %%
# value_counts

movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values

virat_ser
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
virat_ser.sort_values() #ascending
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
virat_ser.sort_values(ascending = False)  #descending
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
virat_ser.sort_values(ascending = False).head(1)
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
# sort_index --> sorts the index

movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Mathematical Methods

# %%
vk = pd.read_csv("/content/kohli_ipl.csv", index_col="match_no").squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# count -> returns total no. of items in series
vk.count()
# Out:
# np.int64(215)

# %%
subs = pd.read_csv("/content/subs.csv").squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# --> sum and prod

# sum
subs.sum()
# Out:
# np.int64(49510)

# %%
# prod

subs.prod()
# Out:
# np.int64(0)

# %%
# mean / medaian / mode / std / var
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
# median
vk.median()
# Out:
# 24.0

# %%
# mode
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
# std -> standard deviation

subs.std()
# Out:
# 62.67502303725269

# %%
# var -> variation

subs.var()
# Out:
# 3928.1585127201556

# %%
# min / max
print(subs.min())
print(subs.max())
# Out:
# 33
# 396

# %%
# describe

vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# # Series Indexing

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[2] # first index value
# Out:
# np.int64(23)

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies["Why Cheat India"]
# Out:
# 'Emraan Hashmi'

# %% [markdown]
# # Slicing

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[0:15]
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies[10:40:3]
# Out:
# movie
# Amavas                             Ali Asgar
# Total Dhamaal                     Ajay Devgn
# Mard Ko Dard Nahi Hota      Abhimanyu Dasani
# Risknamaa                     Garima Agarwal
# Kesari (film)                   Akshay Kumar
# Gone Kesh                       Deepika Amin
# Kalank                          Varun Dhawan
# PM Narendra Modi                 Boman Irani
# Yeh Hai India                   Gavie Chahal
# Article 15 (film)         Ayushmann Khurrana
# Name: lead, dtype: object

# %%
movies[::-1]
# Out:
# movie
# Awara Paagal Deewana                        Akshay Kumar
# Company (film)                                Ajay Devgn
# Saathiya (film)                             Vivek Oberoi
# Aankhen (2002 film)                     Amitabh Bachchan
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
#                                               ...
# Evening Shadows                         Mona Ambegaonkar
# Why Cheat India                            Emraan Hashmi
# The Accidental Prime Minister (film)         Anupam Kher
# Battalion 609                                Vicky Ahuja
# Uri: The Surgical Strike                   Vicky Kaushal
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Editing Series

# %%
my_marks
# Out:
# nepali     66
# social     70
# english    64
# account    68
# maths      72
# Name: jiban mark's, dtype: int64

# %%
# using indexing
my_marks["account"] = 71

# %%
my_marks
# Out:
# nepali     66
# social     70
# english    64
# account    71
# maths      72
# Name: jiban mark's, dtype: int64

# %%
# what if index doesn't exist
my_marks["com"] = 46

my_marks
# Out:
# nepali     66
# social     70
# english    64
# account    71
# maths      72
# com        46
# Name: jiban mark's, dtype: int64

# %%
#  using slicing
my_marks[2:4] = [75,74]

my_marks
# Out:
# nepali     66
# social     70
# english    75
# account    74
# maths      72
# com        46
# Name: jiban mark's, dtype: int64

# %%
# fancy indexing
my_marks[[0,3,5]] = [0,0,0]

print(my_marks)
# Out:
# nepali      0
# social     70
# english    75
# account     0
# maths      72
# com         0
# Name: jiban mark's, dtype: int64
# /tmp/ipykernel_4860/3301355684.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   my_marks[[0,3,5]] = [0,0,0]

# %% [markdown]
# # Plotting graphs

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind = "bar")
# Out:
# <Axes: xlabel='lead'>
