# %% [markdown]
# <a href="https://colab.research.google.com/github/jiban-khatri/Pandas/blob/main/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating dataframes

# %%
# lists

student_data = [
    [100, 80, 1000000],
    [120, 89, 1100000],
    [60, 73, 800000],
    [75, 79, 850000]
]

df = pd.DataFrame(student_data, columns=["IQ", "Marks", "Package"])
df
# Out:
#     IQ  Marks  Package
# 0  100     80  1000000
# 1  120     89  1100000
# 2   60     73   800000
# 3   75     79   850000

# %%
# using dict

student_dict = {
    "IQ" : [100,120,60,75],
    "Marks": [80,89,73,79],
    "package" : [1000000, 1100000, 800000, 850000]
}

df = pd.DataFrame(student_dict)
df
# Out:
#     IQ  Marks  package
# 0  100     80  1000000
# 1  120     89  1100000
# 2   60     73   800000
# 3   75     79   850000

# %%
# using read csv

ipl = pd.read_csv("/content/ipl-matches.csv", index_col = "ID")
ipl
# Out:
#                City        Date   Season  MatchNumber  \
# ID
# 1312200   Ahmedabad  2022-05-29     2022        Final
# 1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 1312198     Kolkata  2022-05-25     2022   Eliminator
# 1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 1304116      Mumbai  2022-05-22     2022           70
# ...             ...         ...      ...          ...
# 335986      Kolkata  2008-04-20  2007/08            4
# 335985       Mumbai  2008-04-20  2007/08            5
# 335984        Delhi  2008-04-19  2007/08            3
# 335983   Chandigarh  2008-04-19  2007/08            2
# 335982    Bangalore  2008-04-18  2007/08            1
#
#                                Team1                        Team2  \
# ID
# 1312200             Rajasthan Royals               Gujarat Titans
# 1312199  Royal Challengers Bangalore             Rajasthan Royals
# 1312198  Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies = pd.read_csv("movies.csv")
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # Dataframe attributes and methods

# %%
# shape
ipl.shape
# Out:
# (950, 19)

# %%
# dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# Index([1312200, 1312199, 1312198, 1312197, 1304116, 1304115, 1304114, 1304113,
#        1304112, 1304111,
#        ...
#         335991,  335990,  335989,  335988,  335987,  335986,  335985,  335984,
#         335983,  335982],
#       dtype='int64', name='ID', length=950)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# values
ipl.values
# Out:
# array([['Ahmedabad', '2022-05-29', '2022', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        ['Ahmedabad', '2022-05-27', '2022', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        ['Kolkata', '2022-05-25', '2022', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        ['Delhi', '2008-04-19', '2007/08', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
print(ipl.head(2))
print("--------------------------------------------------------------------------------------------------")
print(ipl.tail(2))
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                                Team1             Team2  \
# ID
# 1312200             Rajasthan Royals    Gujarat Titans
# 1312199  Royal Challengers Bangalore  Rajasthan Royals
#
#                                     Venue        TossWinner TossDecision  \
# ID
# 1312200  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat
# 1312199  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field
#
#         SuperOver       WinningTeam    WonBy  Margin method Player_of_Match  \
# ID
# 1312200         N    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1312199         N  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                               Team1Players  \
# ID
# 1312200  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# ...

# %%
# sample
movies.sample(3)
# Out:
#                   title_x    imdb_id  \
# 1078       Dus Kahaniyaan  tt0823451
# 172   Wedding Anniversary  tt6499258
# 1573  Yaadein (2001 film)  tt0248617
#
#                                             poster_path  \
# 1078  https://upload.wikimedia.org/wikipedia/en/thum...
# 172   https://upload.wikimedia.org/wikipedia/en/thum...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link              title_y  \
# 1078       https://en.wikipedia.org/wiki/Dus_Kahaniyaan       Dus Kahaniyaan
# 172   https://en.wikipedia.org/wiki/Wedding_Annivers...  Wedding Anniversary
# 1573  https://en.wikipedia.org/wiki/Yaadein_(2001_film)           Yaadein...
#
#            original_title  is_adult  year_of_release runtime  \
# 1078       Dus Kahaniyaan         0             2007     110
# 172   Wedding Anniversary         0             2017     108
# 1573           Yaadein...         0             2001     171
#
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 950 entries, 1312200 to 335982
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             899 non-null    object
#  1   Date             950 non-null    object
#  2   Season           950 non-null    object
#  3   MatchNumber      950 non-null    object
#  4   Team1            950 non-null    object
#  5   Team2            950 non-null    object
#  6   Venue            950 non-null    object
#  7   TossWinner       950 non-null    object
#  8   TossDecision     950 non-null    object
#  9   SuperOver        946 non-null    object
#  10  WinningTeam      946 non-null    object
#  11  WonBy            950 non-null    object
#  12  Margin           932 non-null    float64
#  13  method           19 non-null     object
#  14  Player_of_Match  946 non-null    object
#  15  Team1Players     950 non-null    object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#            Margin
# count  932.000000
# mean    17.056867
# std     21.633109
# min      1.000000
# 25%      6.000000
# 50%      8.000000
# 75%     19.000000
# max    146.000000

# %%
# isnull

movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# Out:
#                City        Date   Season  MatchNumber  \
# ID
# 1312200   Ahmedabad  2022-05-29     2022        Final
# 1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 1312198     Kolkata  2022-05-25     2022   Eliminator
# 1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 1304116      Mumbai  2022-05-22     2022           70
# ...             ...         ...      ...          ...
# 335986      Kolkata  2008-04-20  2007/08            4
# 335985       Mumbai  2008-04-20  2007/08            5
# 335984        Delhi  2008-04-19  2007/08            3
# 335983   Chandigarh  2008-04-19  2007/08            2
# 335982    Bangalore  2008-04-18  2007/08            1
#
#                                Team1                        Team2  \
# ID
# 1312200             Rajasthan Royals               Gujarat Titans
# 1312199  Royal Challengers Bangalore             Rajasthan Royals
# 1312198  Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# rename
df
# Out:
#     IQ  Marks  package
# 0  100     80  1000000
# 1  120     89  1100000
# 2   60     73   800000
# 3   75     79   850000

# %%
df.rename(columns={'package' : 'pkg'})
# Out:
#     IQ  Marks      pkg
# 0  100     80  1000000
# 1  120     89  1100000
# 2   60     73   800000
# 3   75     79   850000

# %% [markdown]
# # Mathematical Functions

# %%
# sum -> axis
df.sum()
# Out:
# IQ             355
# Marks          321
# package    3750000
# dtype: int64

# %%
df.sum(axis = 1)  #row wise
# Out:
# 0    1000180
# 1    1100209
# 2     800133
# 3     850154
# dtype: int64

# %% [markdown]
# # Selecting cols from Dataframe

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# single column
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl['City']
# Out:
# ID
# 1312200     Ahmedabad
# 1312199     Ahmedabad
# 1312198       Kolkata
# 1312197       Kolkata
# 1304116        Mumbai
#               ...
# 335986        Kolkata
# 335985         Mumbai
# 335984          Delhi
# 335983     Chandigarh
# 335982      Bangalore
# Name: City, Length: 950, dtype: object

# %%
# multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
ipl[["Team1","Team2","WinningTeam"]]
# Out:
#                                Team1                        Team2  \
# ID
# 1312200             Rajasthan Royals               Gujarat Titans
# 1312199  Royal Challengers Bangalore             Rajasthan Royals
# 1312198  Royal Challengers Bangalore         Lucknow Super Giants
# 1312197             Rajasthan Royals               Gujarat Titans
# 1304116          Sunrisers Hyderabad                 Punjab Kings
# ...                              ...                          ...
# 335986         Kolkata Knight Riders              Deccan Chargers
# 335985                Mumbai Indians  Royal Challengers Bangalore
# 335984              Delhi Daredevils             Rajasthan Royals
# 335983               Kings XI Punjab          Chennai Super Kings
# 335982   Royal Challengers Bangalore        Kolkata Knight Riders
#
#                          WinningTeam
# ID
# 1312200               Gujarat Titans
# 1312199             Rajasthan Royals
# 1312198  Royal Challengers Bangalore
# ...

# %% [markdown]
# # Selecting Rows
# * iloc - searches using index position
# * loc - searches using index labels

# %%
# iloc
# single row
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
# multiple rows
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# fancy indexing
movies.iloc[[1,3,7]]
# Out:
#            title_x    imdb_id  \
# 1    Battalion 609  tt9472208
# 3  Why Cheat India  tt8108208
# 7       Bombairiya  tt4971258
#
#                                          poster_path  \
# 1                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 7       https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
#
#     original_title  is_adult  year_of_release runtime              genres  \
# 1    Battalion 609         0             2019     131                 War
# 3  Why Cheat India         0             2019     121         Crime|Drama
# 7       Bombairiya         0             2019     104  Comedy|Crime|Drama
#
# ...

# %% [markdown]
# # Selecting both rows and cols

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.iloc[0:3, 0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering a dataframe

# %%
# find all ipl winners
mask = ipl["MatchNumber"] == "Final"
new_df = ipl[mask]
new_df[['Season','WinningTeam']].sort_values("Season")
# Out:
#           Season            WinningTeam
# ID
# 336040   2007/08       Rajasthan Royals
# 392239      2009        Deccan Chargers
# 419165   2009/10    Chennai Super Kings
# 501271      2011    Chennai Super Kings
# 548381      2012  Kolkata Knight Riders
# 598073      2013         Mumbai Indians
# 734049      2014  Kolkata Knight Riders
# 829823      2015         Mumbai Indians
# 981019      2016    Sunrisers Hyderabad
# 1082650     2017         Mumbai Indians
# 1136620     2018    Chennai Super Kings
# 1181768     2019         Mumbai Indians
# 1237181  2020/21         Mumbai Indians
# 1254117     2021    Chennai Super Kings
# 1312200     2022         Gujarat Titans

# %%
# how many super over finishes have occured
mask = ipl["SuperOver"] == "Y"
new_df = ipl[mask]
super_over = new_df['SuperOver'].shape[0]

print(super_over)
# Out:
# 14

# %%
# how many matches has csk won in kolkata
ipl[(ipl['WinningTeam'] == "Chennai Super Kings") & (ipl['City'] == "Kolkata")].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
toss_match_winner = ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
total_match = ipl.shape[0]

per = (toss_match_winner / total_match) * 100
per
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes > 10000

movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5

mask1 = movies['genres'].str.split("|").apply(lambda x : "Action" in x)
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2].shape[0]
# Out:
# 33

# %% [markdown]
# # Adding New Cols

# %%
movies["Country"] = "India"

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...
